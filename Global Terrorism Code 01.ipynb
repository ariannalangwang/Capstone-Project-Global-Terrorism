# %% [markdown]
# ## Global Terrorism Python Code

# %%
import pandas as pd
from datetime import datetime
from random import *
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import plotly.plotly as py
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# for figures to show up in the notebook:
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df.country_txt.value_counts()
# Out:
# Iraq                              20927
# Pakistan                          12879
# Afghanistan                       11046
# India                             10498
# Colombia                           7178
# Philippines                        6024
# Peru                               4750
# United Kingdom                     4732
# El Salvador                        4139
# Turkey                             3807
# Thailand                           3475
# Somalia                            3431
# Nigeria                            3256
# Yemen                              3031
# Spain                              2964
# Sri Lanka                          2872
# Algeria                            2701
# United States                      2588
# Lebanon                            2386
# Russia                             2138
# West Bank and Gaza Strip           2091
# Egypt                              2074
# Israel                             2062
# France                             2056
# Libya                              1986
# Syria                              1881
# Nicaragua                          1870
# South Africa                       1865
# Guatemala                          1855
# Chile                              1810
#                                   ...
# Western Sahara                        5
# Grenada                               5
# Iceland                               4
# Malawi                                4
# Comoros                               4
# Solomon Islands                       4
# Gabon                                 4
# Dominica                              3
# People's Republic of the Congo        3
# Gambia                                3
# French Polynesia                      3
# Barbados                              3
# Mauritius                             2
# South Yemen                           2
# St. Kitts and Nevis                   2
# Turkmenistan                          2
# Equatorial Guinea                     2
# Seychelles                            2
# Vanuatu                               2
# North Korea                           1
# South Vietnam                         1
# Brunei                                1
# International                         1
# New Hebrides                          1
# Andorra                               1
# Antigua and Barbuda                   1
# Vatican City                          1
# Falkland Islands                      1
# St. Lucia                             1
# Wallis and Futuna                     1
# Name: country_txt, Length: 205, dtype: int64

# %%
df = pd.read_csv('global_terrorism_db_0617dist.csv', encoding="ISO-8859-1")
# Out:
# /Users/langwang/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (4,6,31,33,53,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170351 entries, 0 to 170350
# Columns: 135 entries, eventid to related
# dtypes: float64(77), object(58)
# memory usage: 175.5+ MB

# %%
df.head(4)
# Out:
#         eventid   iyear  imonth  iday approxdate  extended resolution  \
# 0  1.970000e+11  1970.0     7.0   2.0        NaN       0.0        NaN
# 1  1.970000e+11  1970.0     0.0   0.0        NaN       0.0        NaN
# 2  1.970000e+11  1970.0     1.0   0.0        NaN       0.0        NaN
# 3  1.970000e+11  1970.0     1.0   0.0        NaN       0.0        NaN
#
#    country         country_txt  region   ...    addnotes scite1 scite2  \
# 0     58.0  Dominican Republic     2.0   ...         NaN    NaN    NaN
# 1    130.0              Mexico     1.0   ...         NaN    NaN    NaN
# 2    160.0         Philippines     5.0   ...         NaN    NaN    NaN
# 3     78.0              Greece     8.0   ...         NaN    NaN    NaN
#
#    scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0     NaN      PGIS      0.0       0.0      0.0     0.0      NaN
# 1     NaN      PGIS      0.0       1.0      1.0     1.0      NaN
# 2     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
# 3     NaN      PGIS     -9.0      -9.0      1.0     1.0      NaN
#
# [4 rows x 135 columns]

# %%
list(df.columns)
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
#  'weaptype1',
#  'weaptype1_txt',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weaptype4',
#  'weaptype4_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weapdetail',
#  'nkill',
#  'nkillus',
#  'nkillter',
#  'nwound',
#  'nwoundus',
#  'nwoundte',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'ishostkid',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'ndays',
#  'divert',
#  'kidhijcountry',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransompaid',
#  'ransompaidus',
#  'ransomnote',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'nreleased',
#  'addnotes',
#  'scite1',
#  'scite2',
#  'scite3',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'INT_MISC',
#  'INT_ANY',
#  'related']

# %%
# Subset the df with all the columns I want:
df = df[['iyear','imonth','iday', 'country','country_txt','region','region_txt','provstate','city',
          'latitude', 'longitude','success','suicide','attacktype1', 'attacktype1_txt','targtype1',
          'targtype1_txt','gname','weaptype1','weaptype1_txt','nkill','nwound']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170351 entries, 0 to 170350
# Data columns (total 22 columns):
# iyear              170351 non-null float64
# imonth             170350 non-null float64
# iday               170350 non-null float64
# country            170350 non-null float64
# country_txt        170350 non-null object
# region             170350 non-null float64
# region_txt         170350 non-null object
# provstate          155848 non-null object
# city               169904 non-null object
# latitude           165744 non-null float64
# longitude          165744 non-null float64
# success            170350 non-null float64
# suicide            170350 non-null float64
# attacktype1        170350 non-null float64
# attacktype1_txt    170350 non-null object
# targtype1          170350 non-null float64
# targtype1_txt      170350 non-null object
# gname              170350 non-null object
# weaptype1          170350 non-null float64
# weaptype1_txt      170350 non-null object
# nkill              160668 non-null float64
# nwound             155025 non-null float64
# dtypes: float64(14), object(8)
# memory usage: 28.6+ MB

# %%
# Assert that there are no missing values for iyear column:
assert pd.notnull(df.iyear).all()

# %%
df['iyear'] = df['iyear'].astype(int)

# %%
df['iyear'].head(2)
# Out:
# 0    1970
# 1    1970
# Name: iyear, dtype: int64

# %%
# imonth and iday columns each has only one missing value. I drop them.

# Remove rows in df where all of these two columns contain missing value:
df = df.dropna(subset=['imonth', 'iday'])

# %%
# convert data type:
df['imonth'] = df['imonth'].astype(int)

# %%
# convert data type:
df['iday'] = df['iday'].astype(int)

# %%
# check
df.dtypes
# Out:
# iyear                int64
# imonth               int64
# iday                 int64
# country            float64
# country_txt         object
# region             float64
# region_txt          object
# provstate           object
# city                object
# latitude           float64
# longitude          float64
# success            float64
# suicide            float64
# attacktype1        float64
# attacktype1_txt     object
# targtype1          float64
# targtype1_txt       object
# gname               object
# weaptype1          float64
# weaptype1_txt       object
# nkill              float64
# nwound             float64
# dtype: object

# %%
# how many zeros?
df['iday'].value_counts()
# Out:
# 15    6064
# 1     6020
# 4     5818
# 16    5747
# 10    5699
# 9     5693
# 14    5682
# 3     5679
# 13    5656
# 12    5642
# 11    5615
# 7     5598
# 2     5590
# 28    5567
# 19    5549
# 20    5544
# 27    5525
# 8     5501
# 17    5498
# 5     5498
# 18    5484
# 25    5480
# 22    5466
# 26    5460
# 23    5424
# 6     5422
# 21    5420
# 24    5372
# 29    5152
# 30    4706
# 31    2888
# 0      891
# Name: iday, dtype: int64

# %%
# how many zeros?
df['imonth'].value_counts()
# Out:
# 5     15771
# 7     15247
# 8     14802
# 10    14728
# 3     14284
# 6     14258
# 4     14213
# 11    14064
# 1     14036
# 9     13246
# 2     12975
# 12    12706
# 0        20
# Name: imonth, dtype: int64

# %%
# replace zeros
df['imonth'].replace(to_replace=0, value=randint(1, 12), inplace=True)

# %%
# check
df['imonth'].value_counts()
# Out:
# 5     15771
# 7     15247
# 8     14802
# 10    14748
# 3     14284
# 6     14258
# 4     14213
# 11    14064
# 1     14036
# 9     13246
# 2     12975
# 12    12706
# Name: imonth, dtype: int64

# %%
# replace zeros
df['iday'].replace(to_replace=0, value=randint(1, 28), inplace=True)

# %%
# check
df['iday'].value_counts()
# Out:
# 11    6506
# 15    6064
# 1     6020
# 4     5818
# 16    5747
# 10    5699
# 9     5693
# 14    5682
# 3     5679
# 13    5656
# 12    5642
# 7     5598
# 2     5590
# 28    5567
# 19    5549
# 20    5544
# 27    5525
# 8     5501
# 5     5498
# 17    5498
# 18    5484
# 25    5480
# 22    5466
# 26    5460
# 23    5424
# 6     5422
# 21    5420
# 24    5372
# 29    5152
# 30    4706
# 31    2888
# Name: iday, dtype: int64

# %%
# Combine the first three columns as dateTime object
df['date']=df.apply(lambda x:datetime.strptime("{0} {1} {2}".format(x['iyear'],x['imonth'], x['iday']),"%Y %m %d"),axis=1)

# %%
# Set the date column as the df index:
df.index = df['date']

# %%
# check that index is indeed Datetime now.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 170350 entries, 1970-07-02 to 2016-12-30
# Data columns (total 23 columns):
# iyear              170350 non-null int64
# imonth             170350 non-null int64
# iday               170350 non-null int64
# country            170350 non-null float64
# country_txt        170350 non-null object
# region             170350 non-null float64
# region_txt         170350 non-null object
# provstate          155848 non-null object
# city               169904 non-null object
# latitude           165744 non-null float64
# longitude          165744 non-null float64
# success            170350 non-null float64
# suicide            170350 non-null float64
# attacktype1        170350 non-null float64
# attacktype1_txt    170350 non-null object
# targtype1          170350 non-null float64
# targtype1_txt      170350 non-null object
# gname              170350 non-null object
# weaptype1          170350 non-null float64
# weaptype1_txt      170350 non-null object
# nkill              160668 non-null float64
# nwound             155025 non-null float64
# date               170350 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(3), object(8)
# memory usage: 31.2+ MB

# %%
# Convert data types for some columns from float to int:
float_list = ['country','region', 'success','suicide', 'attacktype1', 'targtype1', 'weaptype1']
for column_name in float_list:
    df[column_name] = df[column_name].astype(int)

# %%
# Check 'success' column:
df['success'].value_counts()
# Out:
# 1    152701
# 0     17649
# Name: success, dtype: int64

# %%
# Check 'suicide' column:
df['suicide'].value_counts()
# Out:
# 0    164580
# 1      5770
# Name: suicide, dtype: int64

# %%
# Convert 'success' and 'suicide' columns to categorical data type:
df['success'] = df['success'].astype('category')
df['suicide'] = df['suicide'].astype('category')

# %%
# Rename some columns:
df.rename(columns={'iyear':'year', 'imonth':'month', 'iday':'day', 'country':'country_id',
                    'region':'region_id', 'attacktype1':'attacktype_id', 'attacktype1_txt':'attacktype_txt',
                    'targtype1':'targtype_id', 'targtype1_txt':'targtype_txt', 'gname':'gang_name',
                    'weaptype1':'weaptype_id', 'weaptype1_txt':'weaptype_txt', 'nkill':'n_killed', 
                    'nwound':'n_wound'}, inplace=True)

# %%
# drop duplicate data:
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 158285 entries, 1970-07-02 to 2016-12-30
# Data columns (total 23 columns):
# year              158285 non-null int64
# month             158285 non-null int64
# day               158285 non-null int64
# country_id        158285 non-null int64
# country_txt       158285 non-null object
# region_id         158285 non-null int64
# region_txt        158285 non-null object
# provstate         145549 non-null object
# city              157850 non-null object
# latitude          154252 non-null float64
# longitude         154252 non-null float64
# success           158285 non-null category
# suicide           158285 non-null category
# attacktype_id     158285 non-null int64
# attacktype_txt    158285 non-null object
# targtype_id       158285 non-null int64
# targtype_txt      158285 non-null object
# gang_name         158285 non-null object
# weaptype_id       158285 non-null int64
# weaptype_txt      158285 non-null object
# n_killed          149762 non-null float64
# n_wound           144340 non-null float64
# date              158285 non-null datetime64[ns]
# dtypes: category(2), datetime64[ns](1), float64(4), int64(8), object(8)
# memory usage: 26.9+ MB

# %%
# Looking for outliers:
df[['n_killed', 'n_wound']].describe()
# Out:
#             n_killed        n_wound
# count  149762.000000  144340.000000
# mean        2.527564       3.399494
# std        11.698295      35.883294
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         1.000000       0.000000
# 75%         2.000000       2.000000
# max      1500.000000    7366.000000

# %%
# show dataframe where more than 1,000 people killed
df[df.n_killed>=1000]
# Out:
#             year  month  day  country_id    country_txt  region_id  \
# date
# 1994-04-13  1994      4   13         168         Rwanda         11
# 2001-09-11  2001      9   11         217  United States          1
# 2001-09-11  2001      9   11         217  United States          1
# 2014-06-12  2014      6   12          95           Iraq         10
#
#                             region_txt provstate           city   latitude  \
# date
# 1994-04-13          Sub-Saharan Africa    Kigali         Gikoro  -1.932787
# 2001-09-11               North America  New York  New York City  40.712784
# 2001-09-11               North America  New York  New York City  40.712784
# 2014-06-12  Middle East & North Africa   Saladin         Tikrit  34.596934
#
#               ...      attacktype_id               attacktype_txt targtype_id  \
# date          ...
# 1994-04-13    ...                  2                Armed Assault          14
# 2001-09-11    ...                  4                    Hijacking          14
# 2001-09-11    ...                  4                    Hijacking          14
# 2014-06-12    ...                  6  Hostage Taking (Kidnapping)           4
#
#                            targtype_txt  \
# date
# 1994-04-13  Private Citizens & Property
# 2001-09-11  Private Citizens & Property
# 2001-09-11  Private Citizens & Property
# 2014-06-12                     Military
#
#                                               gang_name  weaptype_id  \
# date
# 1994-04-13                              Hutu extremists            5
# 2001-09-11                                     Al-Qaida           10
# 2001-09-11                                     Al-Qaida           10
# 2014-06-12  Islamic State of Iraq and the Levant (ISIL)            5
#
#                                                  weaptype_txt n_killed  \
# date
# 1994-04-13                                           Firearms   1180.0
# 2001-09-11  Vehicle (not to include vehicle-borne explosiv...   1383.0
# 2001-09-11  Vehicle (not to include vehicle-borne explosiv...   1382.0
# 2014-06-12                                           Firearms   1500.0
#
#             n_wound       date
# date
# 1994-04-13      0.0 1994-04-13
# 2001-09-11   7366.0 2001-09-11
# 2001-09-11   7365.0 2001-09-11
# 2014-06-12      NaN 2014-06-12
#
# [4 rows x 23 columns]

# %%
# show dataframe where more than 7,000 people wounded:
df[df.n_wound>=7000]
# Out:
#             year  month  day  country_id    country_txt  region_id  \
# date
# 2001-09-11  2001      9   11         217  United States          1
# 2001-09-11  2001      9   11         217  United States          1
#
#                region_txt provstate           city   latitude    ...      \
# date                                                             ...
# 2001-09-11  North America  New York  New York City  40.712784    ...
# 2001-09-11  North America  New York  New York City  40.712784    ...
#
#             attacktype_id attacktype_txt targtype_id  \
# date
# 2001-09-11              4      Hijacking          14
# 2001-09-11              4      Hijacking          14
#
#                            targtype_txt gang_name  weaptype_id  \
# date
# 2001-09-11  Private Citizens & Property  Al-Qaida           10
# 2001-09-11  Private Citizens & Property  Al-Qaida           10
#
#                                                  weaptype_txt n_killed  \
# date
# 2001-09-11  Vehicle (not to include vehicle-borne explosiv...   1383.0
# 2001-09-11  Vehicle (not to include vehicle-borne explosiv...   1382.0
#
#             n_wound       date
# date
# 2001-09-11   7366.0 2001-09-11
# 2001-09-11   7365.0 2001-09-11
#
# [2 rows x 23 columns]

# %%
# visualize the outliers for the two columns:
df[['n_killed', 'n_wound']].plot.box()

# %%
df.head(1)
# Out:
#             year  month  day  country_id         country_txt  region_id  \
# date
# 1970-07-02  1970      7    2          58  Dominican Republic          2
#
#                              region_txt provstate           city   latitude  \
# date
# 1970-07-02  Central America & Caribbean       NaN  Santo Domingo  18.456792
#
#               ...      attacktype_id attacktype_txt targtype_id  \
# date          ...
# 1970-07-02    ...                  1  Assassination          14
#
#                            targtype_txt gang_name  weaptype_id weaptype_txt  \
# date
# 1970-07-02  Private Citizens & Property    MANO-D           13      Unknown
#
#            n_killed  n_wound       date
# date
# 1970-07-02      1.0      0.0 1970-07-02
#
# [1 rows x 23 columns]

# %% [markdown]
# ----
# ### Exploratory Data Analysis

# %%
# Set Style
sns.set_style('white')

# %%
# Number of Terrorist Attacks from 1970 to 2016:
plt.figure(figsize=(24, 8))
sns.countplot('year', data=df)
plt.title('Number of Terrorist Attacks from 1970 to 2016', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5,0,'Year')

# %%
# Trend of Number of People Killed in Terrorist Attacks from 1970 to 2016   
df.plot.scatter(x='year', y='n_killed', figsize=(24, 8))
plt.title('Trend of Number of People Killed in Terrorist Attacks from 1970 to 2016', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5,0,'Year')

# %%
# Trend of Number of People Wounded in Terrorist Attacks from 1970 to 2016   
df.plot.scatter(x='year', y='n_wound', figsize=(24, 8), lw=4)
plt.title('Trend of Number of People Wounded in Terrorist Attacks from 1970 to 2016', fontsize=25)
plt.xticks(rotation=90, fontsize=15) 
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5,0,'Year')

# %%
# Number of Terrorist Attacks by Region:
plt.figure(figsize=(24, 8))
sns.countplot('region_txt', data=df)
plt.title('Number of Terrorist Attacks by Region', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Region', fontsize=20)
# Out:
# Text(0.5,0,'Region')

# %%
# Number of Terrorist Attacks by Attack Types:
plt.figure(figsize=(24, 8))
sns.countplot('attacktype_txt', data=df)
plt.title('Number of Terrorist Attacks by Attack Types', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Attack Type', fontsize=20)
# Out:
# Text(0.5,0,'Attack Type')

# %%
# Number of Terrorist Attacks by Target Types:
plt.figure(figsize=(24, 8))
sns.countplot('targtype_txt', data=df)
plt.title('Number of Terrorist Attacks by Target Types', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Target Type', fontsize=20)
# Out:
# Text(0.5,0,'Target Type')

# %%
df_attacktype = df.groupby('attacktype_txt')[['n_killed']].count()

# %%
df_attacktype.reset_index(inplace=True)

# %%
df_attacktype
# Out:
#                         attacktype_txt  n_killed
# 0                        Armed Assault     36577
# 1                        Assassination     17715
# 2                    Bombing/Explosion     72378
# 3       Facility/Infrastructure Attack      7723
# 4                            Hijacking       546
# 5  Hostage Taking (Barricade Incident)       746
# 6          Hostage Taking (Kidnapping)      7806
# 7                      Unarmed Assault       804
# 8                              Unknown      5467

# %%
# Number of People Killed by Terrorist Attack Types: 
df_attacktype.plot(x='attacktype_txt', y='n_killed', figsize=(24, 8), lw=4)
plt.title('Number of People Killed by Terrorist Attack Types', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Attack Type', fontsize=20)
# Out:
# Text(0.5,0,'Attack Type')

# %%
# Number of Terrorist Attacks and Number of People Killed by Attack Types:

# Overlay two graphs:
fig, ax = plt.subplots(figsize=(24, 8))
sns.countplot('attacktype_txt', data=df, ax=ax)
df_attacktype.plot(x='attacktype_txt', y='n_killed', figsize=(24, 8), lw=4, ax=ax)
plt.title('Number of Terrorist Attacks and Number of People Killed by Attack Types', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Attack Type', fontsize=20)
# Out:
# Text(0.5,0,'Attack Type')

# %%
# Make a frequency table of year and region:
df_region = pd.crosstab(index=df.year, columns=df.region_txt)  
df_region
# Out:
# region_txt  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# year
# 1970                            1                            7             0
# 1971                            1                            5             0
# 1972                            2                            3             0
# 1973                            1                            6             0
# 1974                            1                           11             0
# 1975                            0                            9             0
# 1976                            0                           44             0
# 1977                            0                           23             0
# 1978                            2                          190             0
# 1979                            2                          511             0
# 1980                            7                          934             0
# 1981                            3                         1036             0
# 1982                            2                          882             0
# 1983                            0                          824             0
# 1984                           11                          610             0
# 1985                            7                          574             0
# 1986                            4                          311             0
# 1987                            3                          416             0
# 1988                           12                          363             0
# 1989                           29                          439             0
# 1990                           18                          212             0
# 1991                           10                          578             7
# 1992                           17                          199            74
# 1994                           14                          164            63
# 1995                           18                          121            55
# 1996                           17                          107            30
# 1997                            7                          103            45
# 1998                            6                            1            24
# 1999                            4                            8            23
# 2000                            6                           14            21
# 2001                            4                            7            18
# 2002                            2                            3             6
# 2003                            4                            6             7
# 2004                            0                            5             8
# 2005                            0                            3            11
# 2006                            2                            5             6
# 2007                            1                            4             4
# 2008                            6                            0            36
# 2009                            1                            9            31
# 2010                            1                            1             9
# 2011                            0                            1             9
# 2012                            0                            1            12
# 2013                            1                           13             6
# 2014                            8                            5             9
# 2015                           14                            1             9
# 2016                           10                            3            16
#
# region_txt  East Asia  Eastern Europe  Middle East & North Africa  \
# year
# 1970                2              12                          28
# 1971                1               3                          55
# 1972                0               1                          35
# 1973                2               1                          19
# 1974                4               2                          38
# 1975                9               0                          40
# 1976                2               0                          52
# 1977                3               2                         191
# 1978               34               2                         122
# 1979               16               1                         421
# 1980                1               1                         409
# 1981                4               4                         306
# 1982                3               3                         288
# 1983               13               2                         326
# 1984               13               4                         251
# 1985                7               5                         127
# 1986               12               3                         195
# 1987                9               1                         188
# 1988               23               2                         231
# 1989               17              16                         444
# 1990               75              57                         480
# 1991               29              82                         541
# 1992               56              90                        1092
# 1994               34              92                        1009
# 1995               36              68                         568
# 1996               42             161                         367
# 1997               36             231                         529
# 1998                8             100                         247
# 1999                4             137                         310
# 2000               12             232                         270
# 2001               17             248                         360
# 2002                4             112                         325
# 2003                6              97                         291
# 2004                4              44                         481
# 2005                2              71                         878
# 2006                1              70                        1164
# 2007                0              62                        1353
# 2008               25             208                        1510
# 2009                8             165                        1352
# 2010                1             256                        1433
# 2011                4             194                        1627
# 2012                4             169                        2330
# 2013               13             162                        4392
# 2014               39             929                        6493
# 2015               28             623                        5751
# 2016                8             132                        5517
#
# region_txt  North America  South America  South Asia  Southeast Asia  \
# year
# 1970                  447             62           1              10
# 1971                  232             22           0               6
# 1972                   61             17           1              10
# 1973                   62             81           1               2
# 1974                   96             61           2               3
# 1975                  139             51           4               7
# 1976                  106             88           4              12
# 1977                  130            110           2               8
# 1978                  106            208           2              35
# 1979                   74            224          33              79
# 1980                   74            270          12              76
# 1981                   71            360          23              49
# 1982                   79            552          20              43
# 1983                   46            845          59              21
# 1984                   65           1162         191              44
# 1985                   40            854         150              88
# 1986                   52            863         270              91
# 1987                   33            934         318             140
# 1988                   28            931         767             236
# 1989                   43           1095         883             200
# 1990                   37            869         546             319
# 1991                   38           1029         616             194
# 1992                   41            977         506             266
# 1994                  100            293         298             151
# 1995                   88            230         655             127
# 1996                  102            397         580             143
# 1997                  118            635         401             123
# 1998                   33             88         125              32
# 1999                   56            127         221             107
# 2000                   39            135         346             238
# 2001                   47            221         384             172
# 2002                   33            158         326             106
# 2003                   30            107         352             145
# 2004                   12             41         369              94
# 2005                   20             49         594             199
# 2006                   14             49         927             269
# 2007                   19             47         968             333
# 2008                   30            139        1704             506
# 2009                   15            159        1925             556
# 2010                   23            142        1919             457
# 2011                   12            106        2071             335
# 2012                   37            133        3745             578
# 2013                   31            176        4495            1145
# 2014                   34            272        4880            1044
# 2015                   56            171        4409            1024
# 2016                   72            131        3569            1055
#
# region_txt  Sub-Saharan Africa  Western Europe
# year
# 1970                         3              47
# 1971                         2             124
# 1972                         0             340
# 1973                         4             285
# 1974                         7             309
# 1975                        12             421
# 1976                        10             533
# 1977                        29             676
# 1978                        45             669
# 1979                       124             812
# 1980                        52             551
# 1981                        84             465
# 1982                        58             367
# 1983                       102             395
# 1984                       119             489
# 1985                       139             378
# 1986                       181             423
# 1987                       166             375
# 1988                       318             438
# 1989                       279             393
# 1990                       290             351
# 1991                       268             551
# 1992                       550             674
# 1994                       411             490
# 1995                       230             286
# 1996                       198             396
# 1997                       231             264
# 1998                        87             133
# 1999                       141             226
# 2000                       185             241
# 2001                       160             224
# 2002                       119             105
# 2003                        73             110
# 2004                        35              54
# 2005                        58              97
# 2006                       111              94
# 2007                       302              68
# 2008                       377             153
# 2009                       278             165
# 2010                       322             129
# 2011                       482              91
# 2012                      1092             137
# 2013                       956             247
# 2014                      2272             211
# 2015                      1878             327
# 2016                      1986             266

# %%
# Number of Terrorist Attackes by Region from 1970 to 2016:
df_region.plot(figsize=(24, 14), lw=2)
plt.legend(fontsize=25)
plt.title('Number of Terrorist Attackes by Region from 1970 to 2016', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5,0,'Year')

# %%
# Make a frequency table of region and attack types:
df_region_attack = pd.crosstab(index=df.region_txt, columns=df.attacktype_txt)  
df_region_attack
# Out:
# attacktype_txt               Armed Assault  Assassination  Bombing/Explosion  \
# region_txt
# Australasia & Oceania                   49             30                 73
# Central America & Caribbean           4171           1189               2128
# Central Asia                           114            114                218
# East Asia                              100             54                254
# Eastern Europe                        1193            385               2625
# Middle East & North Africa            8565           4004              26755
# North America                          381            236               1389
# South America                         3480           2538               6698
# South Asia                           10145           3757              19189
# Southeast Asia                        3680           1221               4144
# Sub-Saharan Africa                    5238           1395               4611
# Western Europe                        1545           2867               7323
#
# attacktype_txt               Facility/Infrastructure Attack  Hijacking  \
# region_txt
# Australasia & Oceania                                    66          3
# Central America & Caribbean                             328         26
# Central Asia                                             18          8
# East Asia                                               170         18
# Eastern Europe                                          227         26
# Middle East & North Africa                              873        126
# North America                                           823         18
# South America                                           649         63
# South Asia                                             1618         82
# Southeast Asia                                          749         43
# Sub-Saharan Africa                                      597        115
# Western Europe                                         2072         62
#
# attacktype_txt               Hostage Taking (Barricade Incident)  \
# region_txt
# Australasia & Oceania                                          5
# Central America & Caribbean                                  137
# Central Asia                                                   2
# East Asia                                                      3
# Eastern Europe                                                20
# Middle East & North Africa                                    86
# North America                                                 63
# South America                                                206
# South Asia                                                   100
# Southeast Asia                                                47
# Sub-Saharan Africa                                            73
# Western Europe                                                85
#
# attacktype_txt               Hostage Taking (Kidnapping)  Unarmed Assault  \
# region_txt
# Australasia & Oceania                                 11                8
# Central America & Caribbean                          483               16
# Central Asia                                          45                4
# East Asia                                             14               35
# Eastern Europe                                       216               56
# Middle East & North Africa                          2354              164
# North America                                        112               69
# South America                                       1320               36
# South Asia                                          2935              213
# Southeast Asia                                       658               23
# Sub-Saharan Africa                                  1562               73
# Western Europe                                       269              121
#
# attacktype_txt               Unknown
# region_txt
# Australasia & Oceania             14
# Central America & Caribbean      294
# Central Asia                      16
# East Asia                         23
# Eastern Europe                   109
# Middle East & North Africa      1509
# North America                     30
# South America                    681
# South Asia                      1635
# Southeast Asia                   313
# Sub-Saharan Africa              1163
# Western Europe                   236

# %%
# Heatmap for Region vs. Attack Type:
plt.figure(figsize=(24, 8))
sns.heatmap(df_region_attack, cmap="coolwarm" )
plt.title('Heatmap for Region vs. Attack Type', fontsize=25)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Attack Type', fontsize=20)
plt.xlabel('Region', fontsize=20)
# Out:
# Text(0.5,55.5,'Region')

# %% [markdown]
# ----
# ### U.S.A. Data

# %%
# subset the data frame to U.S. data only:
df_usa = df[df.country_txt == 'United States']

# %%
# check the head of data frame:
df_usa.head(2)
# Out:
#             year  month  day  country_id    country_txt  region_id  \
# date
# 1970-01-01  1970      1    1         217  United States          1
# 1970-01-02  1970      1    2         217  United States          1
#
#                region_txt   provstate     city   latitude    ...      \
# date                                                         ...
# 1970-01-01  North America    Illinois    Cairo  37.005105    ...
# 1970-01-02  North America  California  Oakland  37.805065    ...
#
#             attacktype_id     attacktype_txt targtype_id  targtype_txt  \
# date
# 1970-01-01              2      Armed Assault           3        Police
# 1970-01-02              3  Bombing/Explosion          21     Utilities
#
#                      gang_name  weaptype_id               weaptype_txt  \
# date
# 1970-01-01  Black Nationalists            5                   Firearms
# 1970-01-02             Unknown            6  Explosives/Bombs/Dynamite
#
#            n_killed  n_wound       date
# date
# 1970-01-01      0.0      0.0 1970-01-01
# 1970-01-02      0.0      0.0 1970-01-02
#
# [2 rows x 23 columns]

# %%
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2588 entries, 1970-01-01 to 2016-12-15
# Data columns (total 23 columns):
# year              2588 non-null int64
# month             2588 non-null int64
# day               2588 non-null int64
# country_id        2588 non-null int64
# country_txt       2588 non-null object
# region_id         2588 non-null int64
# region_txt        2588 non-null object
# provstate         2588 non-null object
# city              2588 non-null object
# latitude          2587 non-null float64
# longitude         2587 non-null float64
# success           2588 non-null category
# suicide           2588 non-null category
# attacktype_id     2588 non-null int64
# attacktype_txt    2588 non-null object
# targtype_id       2588 non-null int64
# targtype_txt      2588 non-null object
# gang_name         2588 non-null object
# weaptype_id       2588 non-null int64
# weaptype_txt      2588 non-null object
# n_killed          2516 non-null float64
# n_wound           2498 non-null float64
# date              2588 non-null datetime64[ns]
# dtypes: category(2), datetime64[ns](1), float64(4), int64(8), object(8)
# memory usage: 450.1+ KB

# %%
df_usa.describe()
# Out:
#               year        month          day  country_id  region_id  \
# count  2588.000000  2588.000000  2588.000000      2588.0     2588.0
# mean   1983.419629     6.232998    15.383308       217.0        1.0
# std      13.510898     3.383976     8.986821         0.0        0.0
# min    1970.000000     1.000000     1.000000       217.0        1.0
# 25%    1971.000000     3.000000     7.000000       217.0        1.0
# 50%    1979.000000     6.000000    15.000000       217.0        1.0
# 75%    1994.000000     9.000000    23.000000       217.0        1.0
# max    2016.000000    12.000000    31.000000       217.0        1.0
#
#           latitude    longitude  attacktype_id  targtype_id  weaptype_id  \
# count  2587.000000  2587.000000    2588.000000  2588.000000  2588.000000
# mean     36.760864   -92.351758       4.241499     6.283617     6.617079
# std       7.293351    21.995961       2.123011     5.687447     1.618831
# min      17.966072  -157.858333       1.000000     1.000000     1.000000
# 25%      34.053490  -118.126287       3.000000     1.000000     6.000000
# 50%      38.890370   -85.766404       3.000000     4.000000     6.000000
# 75%      40.783060   -74.005941       7.000000    10.000000     8.000000
# max      64.837778   105.270546       9.000000    22.000000    13.000000
#
#           n_killed      n_wound
# count  2516.000000  2498.000000
# mean      1.448728     7.239392
# std      39.315982   209.378542
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max    1383.000000  7366.000000

# %%
df_usa.provstate.value_counts()
# Out:
# California              568
# New York                443
# Puerto Rico             220
# Florida                 143
# Illinois                102
# Washington               96
# District of Columbia     79
# Oregon                   63
# Massachusetts            56
# Texas                    55
# Ohio                     49
# Colorado                 44
# New Jersey               43
# Michigan                 41
# Virginia                 38
# Wisconsin                37
# Missouri                 36
# Maryland                 33
# Arizona                  31
# Pennsylvania             31
# Georgia                  29
# North Carolina           28
# Minnesota                24
# Iowa                     23
# Tennessee                21
# Indiana                  21
# Nebraska                 20
# Utah                     20
# New Mexico               19
# Louisiana                18
# Connecticut              17
# Nevada                   16
# Alabama                  15
# Kansas                   13
# Idaho                    13
# Oklahoma                 12
# New Hampshire             9
# Mississippi               8
# South Dakota              7
# Montana                   6
# Arkansas                  5
# Vermont                   5
# North Dakota              5
# South Carolina            5
# Hawaii                    4
# Maine                     4
# Delaware                  3
# Kentucky                  2
# West Virginia             2
# Wyoming                   2
# Rhode Island              2
# Alaska                    1
# Unknown                   1
# Name: provstate, dtype: int64

# %%
# Group the U.S data by state:
state_count = df_usa.groupby('provstate').count()[['date']]
state_count = state_count.reset_index()
state_count.columns = ['state_name', 'num_of_attacks']
state_count.head()
# Out:
#    state_name  num_of_attacks
# 0     Alabama              15
# 1      Alaska               1
# 2     Arizona              31
# 3    Arkansas               5
# 4  California             568

# %%
# Have this state code vs state name dictionary from the internet:
state_dict = {"AL": "Alabama",
    "AK": "Alaska",
    "AS": "American Samoa",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District Of Columbia",
    "FM": "Federated States Of Micronesia",
    "FL": "Florida",
    "GA": "Georgia",
    "GU": "Guam",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MH": "Marshall Islands",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "MP": "Northern Mariana Islands",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PW": "Palau",
    "PA": "Pennsylvania",
    "PR": "Puerto Rico",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VI": "Virgin Islands",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"}

# %%
# reverse the dictionary:
state_dict_reverse = {}
for k, v in state_dict.items():
    state_dict_reverse[v] = k

state_dict_reverse
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'American Samoa': 'AS',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District Of Columbia': 'DC',
#  'Federated States Of Micronesia': 'FM',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Guam': 'GU',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Marshall Islands': 'MH',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Northern Mariana Islands': 'MP',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Palau': 'PW',
#  'Pennsylvania': 'PA',
#  'Puerto Rico': 'PR',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virgin Islands': 'VI',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
# add the state code as a new column to the data frame:
state_count['state_code'] = state_count['state_name'].map(state_dict_reverse)

# %%
# There are only a couple of rows that have missing value, drop them:
state_count.dropna(inplace=True)
state_count
# Out:
#         state_name  num_of_attacks state_code
# 0          Alabama              15         AL
# 1           Alaska               1         AK
# 2          Arizona              31         AZ
# 3         Arkansas               5         AR
# 4       California             568         CA
# 5         Colorado              44         CO
# 6      Connecticut              17         CT
# 7         Delaware               3         DE
# 9          Florida             143         FL
# 10         Georgia              29         GA
# 11          Hawaii               4         HI
# 12           Idaho              13         ID
# 13        Illinois             102         IL
# 14         Indiana              21         IN
# 15            Iowa              23         IA
# 16          Kansas              13         KS
# 17        Kentucky               2         KY
# 18       Louisiana              18         LA
# 19           Maine               4         ME
# 20        Maryland              33         MD
# 21   Massachusetts              56         MA
# 22        Michigan              41         MI
# 23       Minnesota              24         MN
# 24     Mississippi               8         MS
# 25        Missouri              36         MO
# 26         Montana               6         MT
# 27        Nebraska              20         NE
# 28          Nevada              16         NV
# 29   New Hampshire               9         NH
# 30      New Jersey              43         NJ
# 31      New Mexico              19         NM
# 32        New York             443         NY
# 33  North Carolina              28         NC
# 34    North Dakota               5         ND
# 35            Ohio              49         OH
# 36        Oklahoma              12         OK
# 37          Oregon              63         OR
# 38    Pennsylvania              31         PA
# 39     Puerto Rico             220         PR
# 40    Rhode Island               2         RI
# 41  South Carolina               5         SC
# 42    South Dakota               7         SD
# 43       Tennessee              21         TN
# 44           Texas              55         TX
# 46            Utah              20         UT
# 47         Vermont               5         VT
# 48        Virginia              38         VA
# 49      Washington              96         WA
# 50   West Virginia               2         WV
# 51       Wisconsin              37         WI
# 52         Wyoming               2         WY

# %%
data = dict(type='choropleth',
            colorscale = 'YIOrRd',
            locations = state_count['state_code'],
            z = state_count['num_of_attacks'],
            locationmode = 'USA-states',
            text = state_count['state_name'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"Number of Attacks"}
            )

# %%
layout = dict(title = 'Number of Terrorist Attacks in the U.S. from 1970 to 2016',
              geo = dict(scope='usa',
                         showlakes = True,
                         lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
# Out:
# <div id="862bd6f7-d006-4f02-86d8-ac8e2524bab2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("862bd6f7-d006-4f02-86d8-ac8e2524bab2", [{"type": "choropleth", "colorscale": "YIOrRd", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "PR", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "z": [15, 1, 31, 5, 568, 44, 17, 3, 143, 29, 4, 13, 102, 21, 23, 13, 2, 18, 4, 33, 56, 41, 24, 8, 36, 6, 20, 16, 9, 43, 19, 443, 28, 5, 49, 12, 63, 31, 220, 2, 5, 7, 21, 55, 20, 5, 38, 96, 2, 37, 2], "locationmode": "USA-states", "text": ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "colorbar": {"title": "Number of Attacks"}}], {"title": "Number of Terrorist Attacks in the U.S. from 1970 to 2016", "geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# From this graph, we can see that California and New York have the most terrorist attacks from 1970 to 2016.

# %% [markdown]
# ----
# ### Scrap Paper

# %%
df.gang_name.value_counts()
# Out:
# Unknown                                               74320
# Taliban                                                6382
# Islamic State of Iraq and the Levant (ISIL)            3876
# Shining Path (SL)                                      3555
# Al-Shabaab                                             2635
# Farabundo Marti National Liberation Front (FMLN)       2443
# Irish Republican Army (IRA)                            2374
# Revolutionary Armed Forces of Colombia (FARC)          2335
# New People's Army (NPA)                                2329
# Kurdistan Workers' Party (PKK)                         2060
# Boko Haram                                             1974
# Basque Fatherland and Freedom (ETA)                    1845
# Communist Party of India - Maoist (CPI-Maoist)         1721
# Liberation Tigers of Tamil Eelam (LTTE)                1568
# Maoists                                                1390
# National Liberation Army of Colombia (ELN)             1302
# Tehrik-i-Taliban Pakistan (TTP)                        1214
# Palestinians                                           1096
# Al-Qaida in the Arabian Peninsula (AQAP)                960
# Nicaraguan Democratic Force (FDN)                       861
# Houthi extremists (Ansar Allah)                         857
# Sikh Extremists                                         662
# Al-Qaida in Iraq                                        599
# Manuel Rodriguez Patriotic Front (FPMR)                 597
# African National Congress (South Africa)                576
# Donetsk People's Republic                               547
# Muslim extremists                                       538
# Separatists                                             516
# M-19 (Movement of April 19)                             496
# Abu Sayyaf Group (ASG)                                  466
#                                                       ...
# The Third Way (Der III. Weg)                              1
# 28 February Armed Group                                   1
# Pakistan Muslim League (PML)                              1
# 28th of December Group                                    1
# Mlada Bosna                                               1
# Agudat Israel Party                                       1
# Fighters of the People                                    1
# Niger Delta Freedom Fighters (NDDF)                       1
# People's Revolutionary Party (Tanzania)                   1
# Liberals of Galilee                                       1
# Proletarian Initiative and Offensive for W. Europe        1
# Mouhajiroune Brigade                                      1
# Catholic E. Timurese                                      1
# Abdul Ghani Kikli Militia                                 1
# Movement for Democracy and Development (MDD)              1
# Liberia Peace Council                                     1
# Supporters of opposing candidate Abdu Sakurtan            1
# Vyborg Brigade                                            1
# French Armed Islamic Front                                1
# Death to Rustlers                                         1
# Brazilian Democratic Mobilization Party (PMBD)            1
# Fighting Nucleus for Communism                            1
# Communist Brigades                                        1
# Uganda Federal Army                                       1
# Xhosa Tribal Workers                                      1
# Presidential Movement (MP) Militiamen                     1
# Fuerzas Populares Jose Leonardo Chirinos                  1
# Anti-Trump extremists                                     1
# Forbid the Evil Group (Muslim Extremists)                 1
# Anti Kurdish Workers Party Iraq nationals                 1
# Name: gang_name, Length: 3454, dtype: int64
